# %% [markdown]
# # Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.118 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.9/112.6 GB disk)

# %% [markdown]
# # Detection

# %%
# Load YOLO26n, train it on African Wildlife datasert for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n.pt')  # load a pretrained YOLO detection model
# results = model.train(data='african-wildlife.yaml', epochs=3, batch=8)  # train the model

# %% [markdown]
# # Testing and Validating

# %%
img2_results = model("https://images.pexels.com/photos/18341011/pexels-photo-18341011/free-photo-of-elephant-and-zebras-in-savannah.png", save=True)
# Out:
# ...
# image 1/1 /content/free-photo-of-elephant-and-zebras-in-savannah.png: 448x640 1 elephant, 9 zebras, 9.7ms
# Speed: 76.3ms preprocess, 9.7ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict

# %%
img2_results = model('https://github.com/ultralytics/assets/releases/download/v0.0.0/bus.jpg', save=True)
# Out:
# ...
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 59.0ms
# Speed: 2.5ms preprocess, 59.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict

# %%
# Run inference on 'bus.jpg' with arguments
model.predict("https://ultralytics.com/images/bus.jpg", save=True, imgsz=320, conf=0.25)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 320x256 5 persons, 1 bus, 89.7ms
# Speed: 1.4ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
# ...
